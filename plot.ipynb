# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from numpy.random import randn
# stats
from scipy import stats
#plot
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data1 = randn(100)
plt.hist(data1)
# Out:
# (array([  2.,   8.,  19.,  20.,  26.,  13.,   8.,   3.,   0.,   1.]),
#  array([-2.63273568, -1.98178421, -1.33083274, -0.67988127, -0.0289298 ,
#          0.62202167,  1.27297314,  1.92392461,  2.57487607,  3.22582754,
#          3.87677901]),
#  <a list of 10 Patch objects>)

# %%
data2 = randn(100)
plt.hist(data2, color = 'indianred')
# Out:
# (array([  2.,   4.,  15.,  14.,  15.,  14.,  13.,  18.,   3.,   2.]),
#  array([-2.52354378, -2.01258832, -1.50163286, -0.99067739, -0.47972193,
#          0.03123353,  0.542189  ,  1.05314446,  1.56409992,  2.07505539,
#          2.58601085]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data1,normed=True, color = 'indianred', alpha = 0.5, bins=10)
plt.hist(data2,normed=True,  alpha = 0.5, bins=10)
# Out:
# (array([ 0.02199619,  0.10998093,  0.06598856,  0.08798474,  0.37393516,
#          0.41792753,  0.28595042,  0.3079466 ,  0.19796567,  0.10998093]),
#  array([-2.81075468, -2.3056166 , -1.80047852, -1.29534043, -0.79020235,
#         -0.28506427,  0.22007381,  0.72521189,  1.23034997,  1.73548805,
#          2.24062614]),
#  <a list of 10 Patch objects>)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind= 'hex')

# %%
sns.regplot(data1,data2)

# %%
sns.rugplot(data1)
sns.distplot(data1,kde_kws={'color':'red','label':'HIST'})

# %%
ser1 = Series(data1,name= 'myname')
sns.distplot(ser1,bins = 25)

# %%
sns.boxplot(ser1)

# %%
sns.violinplot(ser1)

# %%
df = pd.DataFrame(np.random.randint(0,1000,size=(100, 2)), columns=list('AB'))
df
# Out:
#       A    B
# 0   238  365
# 1   413  535
# 2   536  737
# 3   415  739
# 4   790  423
# 5   318   56
# 6   521  546
# 7    23  873
# 8   359  368
# 9    99  739
# 10  739  285
# 11  861  524
# 12   37   89
# 13  342  426
# 14  630  758
# 15   74  296
# 16  393   52
# 17  972  655
# 18  238  580
# 19  359  228
# 20  123  852
# 21  275  410
# 22  771  748
# 23  941  672
# 24  435  471
# 25  709  497
# 26  877  677
# 27  130  683
# 28  104  759
# 29  773  847
# ..  ...  ...
# 70  467  848
# 71  193  695
# 72  431  466
# 73  230  753
# 74  785  763
# 75  666  215
# 76  771  882
# 77  891  246
# 78  765  385
# 79  291   71
# 80  468  268
# 81  452   12
# 82  899   63
# 83  658  152
# 84  372  955
# 85  345   29
# 86  338  102
# 87  595  891
# 88  468   47
# 89  325  302
# 90  231  234
# 91  933  459
# 92  489  208
# 93  423  164
# 94  797  659
# 95  943  550
# 96   71  841
# 97  538  925
# 98  236  495
# 99  759  266
#
# [100 rows x 2 columns]

# %%
sns.lmplot('A','B',df,order=4,
          scatter_kws = {'marker':'o','color': 'indianred'},
          line_kws = {'linewidth':1,'color':'green' })

# %%
sns.heatmap(df)

# %%
sns.clustermap(df)

# %%
df.head()
# Out:
#      A    B
# 0  238  365
# 1  413  535
# 2  536  737
# 3  415  739
# 4  790  423
