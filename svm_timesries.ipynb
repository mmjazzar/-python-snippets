# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import csv
from pandas import Series,DataFrame

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# importing models
from sklearn import linear_model
from sklearn.svm import SVR
model = SVR()

from sklearn.cross_validation import train_test_split
from sklearn import metrics

# Random forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 2].values

# %%
# reading data
# make sure that the data in the right path

df = pd.read_csv('train.CSV')

df.convert_objects(convert_numeric=True)
#X = df.iloc[:, :-1].values get specific value

#df['ambient.temperature'] = df['ambient.temperature'].astype(float)
#df['module.temperature'] = df['module.temperature'].astype(float)
#df['solar.irradiance'] = df['solar.irradiance'].astype(float)
#df['Output.power'] = df['Output.power'].astype(float)
# Out:
# C:\Users\mmjaz\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#         ambient.temperature  module.temperature  solar.irradiance  \
# 0                      26.4                 0.0              25.4
# 1                      26.2                 0.0              25.1
# 2                      26.2                 0.0              25.0
# 3                      26.1                 0.0              24.9
# 4                      26.0                 0.0              24.7
# 5                      26.0                 0.0              24.7
# 6                      26.0                 0.0              24.7
# 7                      25.9                 0.0              24.7
# 8                      26.0                 0.0              24.7
# 9                      26.0                 0.0              24.8
# ...

# %%
df = df.dropna()

# %%
#df['ambient.temperature'] = df['ambient.temperature'].astype(float)
#df['module.temperature'] = df['module.temperature'].astype(float)
#df['solar.irradiance'] = df['solar.irradiance'].astype(float)
#df['Output.power'] = df['Output.power'].astype(float)

# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df[['ambient.temperature','module.temperature','solar.irradiance']],df['Output.power'])

# %%
model.fit(X_train.dropna(),y_train.dropna())
predicted = model.predict(X_test.dropna())
expected = y_test.dropna()

# %%
X_train.head()
# Out:
#        ambient.temperature  module.temperature  solar.irradiance
# 11432                 35.3               333.0              46.1
# 54348                 27.4                 0.0              26.2
# 42736                 36.0               289.0              44.1
# 6954                  26.8                 0.0              25.6
# 40452                 39.6               586.0              52.0

# %%
y_train.head()
# Out:
# 11432    2834.0
# 54348       0.0
# 42736    3193.0
# 6954        0.0
# 40452    4344.0
# Name: Output.power, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score


#print (metrics.accuracy_score(expected,predicted))
print (mean_absolute_error(expected,predicted))
print (r2_score(expected,predicted, multioutput='variance_weighted'))
# Out:
# 816.347811524
# 0.353529329388

# %%
##Random forest
clf = RandomForestRegressor(n_estimators=10)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
clf.score(X_test, y_test)
# Out:
# 0.94571303513734817

# %%
# Using Linear SVR 
clf = SVR(C=1.0, epsilon=0.2,kernel= "linear").fit(X_train,y_train)
y_pred = clf.predict(X_test)
clf.score(X_test, y_test)

#lin_svc = svm.LinearSVC(C=c).fit(x,y)

# %%
## Using RBF SVR 
rbf_svc = SVR(kernel= "rbf", gamma= 0.7, C=c).fit(X_train,y_train)
y_pred = clf.predict(X_test)
clf.score(X_test, y_test)

# %%
# using Poly SVR 
#poly_svc = SVR(kernel='poly',degree=3, C=c).fit(x,y)
y_pred = clf.predict(X_test)
clf.score(X_test, y_test)
